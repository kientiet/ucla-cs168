# %% [markdown]
# # Package

# %%
import torch
import os
import numpy as np
import matplotlib.pyplot as plt
import pytorch_lightning as pl
from pytorch_lightning import loggers
from pytorch_lightning.callbacks import ModelCheckpoint
from tqdm.notebook import tqdm

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment config

# %%
device = "cuda" if torch.cuda.is_available else "cpu"

def format_bytes(size):
    # 2**10 = 1024
    power = 2**10
    n = 0
    power_labels = {0 : '', 1: 'kilo', 2: 'mega', 3: 'giga', 4: 'tera'}
    while size > power:
        size /= power
        n += 1
    return "%.2f" % size, power_labels[n] + 'bytes'

torch.cuda.get_device_name(), format_bytes(torch.cuda.get_device_properties(device).total_memory)
# Out:
# ('GeForce GTX 1080 Ti', ('10.92', 'gigabytes'))

# %% [markdown]
# # Load data

# %%
from preprocessing.load_dataset import raw_to_dict

# %%
# trainset, valset = raw_to_dict(data_mode = "small")
trainset, valset = raw_to_dict()
# Out:
# 100%|██████████| 75039/75039 [00:00<00:00, 879286.98it/s]
#   0%|          | 0/117273 [00:00<?, ?it/s]
# >> Loading msimut at /home/kientiet/Documents/My Project/python/ucla-cs168/data/msimut
# >> Total running 75039
#
# >> Loading msimut at /home/kientiet/Documents/My Project/python/ucla-cs168/data/mss
# 100%|██████████| 117273/117273 [00:00<00:00, 992605.31it/s]
# >> Total running 117273
#
# >> Splitting the dataset
#
#
# Total amount of train msimut/mss: 52 and 236
#
#
# Total amount of train msimut/mss: 13 and 59
#
# >> Passing the criteria
#
# >> From dictionary to data instance
#
#
# >> Sumary between two classes:
# msimut 65137
# mss 86718
#
#
# >> Sumary between two classes:
# msimut 9902
# mss 30555
#
# >> Done!

# %%
batch_size = 64
trainloader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle = True, num_workers = 4)
valloader = torch.utils.data.DataLoader(valset, batch_size = batch_size, num_workers = 4)
len(trainloader), len(valloader)
# Out:
# (2373, 633)

# %%
images, labels = next(iter(trainloader))

print(images.shape, labels.shape)
def imshow(img):
    inp = img.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    # plt.show()

imshow(images[0])
# Out:
# torch.Size([64, 3, 224, 224]) torch.Size([64])

# %% [markdown]
# # SkNet-DualAttention model

# %%
from trainer.sknet_trainer import SKNetTrainer

# %%
sknet_trainer = SKNetTrainer(trainloader, valloader, num_cycle = 5)
max_epochs = sknet_trainer.get_max_epochs()

# %%
checkpoint_path = os.path.join(os.getcwd(), "checkpoint", "sknet", "full")
checkpoint_callback = ModelCheckpoint(
    filepath = checkpoint_path,
    save_top_k = -1,
    verbose = True,
    monitor = 'val_loss',
    mode = 'min'
)

checkpoint_path
# Out:
# '/home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/full'

# %%
tb_logger = loggers.TensorBoardLogger('logs/', name = "sknet")
trainer = pl.Trainer(checkpoint_callback = checkpoint_callback,
                     nb_sanity_val_steps=0, 
                     max_epochs = max_epochs, 
                     gpus = -1, 
                    logger = tb_logger
                    )
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %%
# from models.sknet import sknet18_32x4d

# %%
# model = sknet18_32x4d(2)
# model = model.to(device)
# torch.cuda.empty_cache()
# model(images.to(device))

# %% [markdown]
# # Learning rate finder

# %%
lr_finder = trainer.lr_find(sknet_trainer)
# Out:
# INFO:lightning:
#     | Name                                                                    | Type              | Params
# ----------------------------------------------------------------------------------------------------------
# 0   | criterion                                                               | BCEWithLogitsLoss | 0
# 1   | model                                                                   | SKNet             | 16 M
# 2   | model.stem_head                                                         | Sequential        | 9 K
# 3   | model.stem_head.0                                                       | Conv2d            | 9 K
# 4   | model.stem_head.1                                                       | BatchNorm2d       | 128
# 5   | model.stem_head.2                                                       | ReLU              | 0
# 6   | model.stem_head.3                                                       | MaxPool2d         | 0
# 7   | model.layer_1                                                           | Sequential        | 187 K
# 8   | model.layer_1.0                                                         | SKBlock           | 89 K
# 9   | model.layer_1.0.basic_block                                             | Sequential        | 72 K
# 10  | model.layer_1.0.basic_block.0                                           | Conv2d            | 8 K
# 11  | model.layer_1.0.basic_block.1                                           | BatchNorm2d       | 256
# 12  | model.layer_1.0.basic_block.2                                           | ReLU              | 0
# 13  | model.layer_1.0.basic_block.3                                           | SKConvolution     | 30 K
# 14  | model.layer_1.0.basic_block.3.conv_blocks                               | ModuleList        | 17 K
# 15  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 4 K
# 16  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 4 K
# 17  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 256
# 18  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 19  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 13 K
# 20  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 12 K
# 21  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 256
# 22  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 23  | model.layer_1.0.basic_block.3.attention_block                           | SKAttention       | 12 K
# 24  | model.layer_1.0.basic_block.3.attention_block.z                         | Sequential        | 4 K
# 25  | model.layer_1.0.basic_block.3.attention_block.z.0                       | Linear            | 4 K
# 26  | model.layer_1.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 27  | model.layer_1.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 28  | model.layer_1.0.basic_block.3.attention_block.projection                | ModuleList        | 8 K
# 29  | model.layer_1.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 4 K
# 30  | model.layer_1.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 4 K
# 31  | model.layer_1.0.basic_block.4                                           | BatchNorm2d       | 256
# 32  | model.layer_1.0.basic_block.5                                           | ReLU              | 0
# 33  | model.layer_1.0.basic_block.6                                           | Conv2d            | 32 K
# 34  | model.layer_1.0.basic_block.7                                           | BatchNorm2d       | 512
# 35  | model.layer_1.0.shortcut                                                | Sequential        | 16 K
# 36  | model.layer_1.0.shortcut.0                                              | Conv2d            | 16 K
# 37  | model.layer_1.0.batch_norm                                              | BatchNorm2d       | 512
# 38  | model.layer_1.1                                                         | SKBlock           | 97 K
# 39  | model.layer_1.1.basic_block                                             | Sequential        | 97 K
# 40  | model.layer_1.1.basic_block.0                                           | Conv2d            | 32 K
# 41  | model.layer_1.1.basic_block.1                                           | BatchNorm2d       | 256
# 42  | model.layer_1.1.basic_block.2                                           | ReLU              | 0
# 43  | model.layer_1.1.basic_block.3                                           | SKConvolution     | 30 K
# 44  | model.layer_1.1.basic_block.3.conv_blocks                               | ModuleList        | 17 K
# 45  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 4 K
# 46  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 4 K
# 47  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 256
# 48  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 49  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 13 K
# 50  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 12 K
# 51  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 256
# 52  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 53  | model.layer_1.1.basic_block.3.attention_block                           | SKAttention       | 12 K
# 54  | model.layer_1.1.basic_block.3.attention_block.z                         | Sequential        | 4 K
# 55  | model.layer_1.1.basic_block.3.attention_block.z.0                       | Linear            | 4 K
# 56  | model.layer_1.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 57  | model.layer_1.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 58  | model.layer_1.1.basic_block.3.attention_block.projection                | ModuleList        | 8 K
# 59  | model.layer_1.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 4 K
# 60  | model.layer_1.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 4 K
# 61  | model.layer_1.1.basic_block.4                                           | BatchNorm2d       | 256
# 62  | model.layer_1.1.basic_block.5                                           | ReLU              | 0
# 63  | model.layer_1.1.basic_block.6                                           | Conv2d            | 32 K
# 64  | model.layer_1.1.basic_block.7                                           | BatchNorm2d       | 512
# 65  | model.layer_1.1.shortcut                                                | Sequential        | 0
# 66  | model.layer_1.1.batch_norm                                              | BatchNorm2d       | 512
# 67  | model.layer_2                                                           | Sequential        | 787 K
# 68  | model.layer_2.0                                                         | SKBlock           | 426 K
# 69  | model.layer_2.0.basic_block                                             | Sequential        | 294 K
# 70  | model.layer_2.0.basic_block.0                                           | Conv2d            | 65 K
# 71  | model.layer_2.0.basic_block.1                                           | BatchNorm2d       | 512
# 72  | model.layer_2.0.basic_block.2                                           | ReLU              | 0
# 73  | model.layer_2.0.basic_block.3                                           | SKConvolution     | 95 K
# 74  | model.layer_2.0.basic_block.3.conv_blocks                               | ModuleList        | 70 K
# 75  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 18 K
# 76  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 18 K
# 77  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 512
# 78  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 79  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 51 K
# 80  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 51 K
# 81  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 512
# 82  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 83  | model.layer_2.0.basic_block.3.attention_block                           | SKAttention       | 25 K
# 84  | model.layer_2.0.basic_block.3.attention_block.z                         | Sequential        | 8 K
# 85  | model.layer_2.0.basic_block.3.attention_block.z.0                       | Linear            | 8 K
# 86  | model.layer_2.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 87  | model.layer_2.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 88  | model.layer_2.0.basic_block.3.attention_block.projection                | ModuleList        | 16 K
# 89  | model.layer_2.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 8 K
# 90  | model.layer_2.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 8 K
# 91  | model.layer_2.0.basic_block.4                                           | BatchNorm2d       | 512
# 92  | model.layer_2.0.basic_block.5                                           | ReLU              | 0
# 93  | model.layer_2.0.basic_block.6                                           | Conv2d            | 131 K
# 94  | model.layer_2.0.basic_block.7                                           | BatchNorm2d       | 1 K
# 95  | model.layer_2.0.shortcut                                                | Sequential        | 131 K
# 96  | model.layer_2.0.shortcut.0                                              | Conv2d            | 131 K
# 97  | model.layer_2.0.batch_norm                                              | BatchNorm2d       | 1 K
# 98  | model.layer_2.1                                                         | SKBlock           | 361 K
# 99  | model.layer_2.1.basic_block                                             | Sequential        | 360 K
# 100 | model.layer_2.1.basic_block.0                                           | Conv2d            | 131 K
# 101 | model.layer_2.1.basic_block.1                                           | BatchNorm2d       | 512
# 102 | model.layer_2.1.basic_block.2                                           | ReLU              | 0
# 103 | model.layer_2.1.basic_block.3                                           | SKConvolution     | 95 K
# 104 | model.layer_2.1.basic_block.3.conv_blocks                               | ModuleList        | 70 K
# 105 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 18 K
# 106 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 18 K
# 107 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 512
# 108 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 109 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 51 K
# 110 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 51 K
# 111 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 512
# 112 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 113 | model.layer_2.1.basic_block.3.attention_block                           | SKAttention       | 25 K
# 114 | model.layer_2.1.basic_block.3.attention_block.z                         | Sequential        | 8 K
# 115 | model.layer_2.1.basic_block.3.attention_block.z.0                       | Linear            | 8 K
# 116 | model.layer_2.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 117 | model.layer_2.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 118 | model.layer_2.1.basic_block.3.attention_block.projection                | ModuleList        | 16 K
# 119 | model.layer_2.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 8 K
# 120 | model.layer_2.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 8 K
# 121 | model.layer_2.1.basic_block.4                                           | BatchNorm2d       | 512
# 122 | model.layer_2.1.basic_block.5                                           | ReLU              | 0
# 123 | model.layer_2.1.basic_block.6                                           | Conv2d            | 131 K
# 124 | model.layer_2.1.basic_block.7                                           | BatchNorm2d       | 1 K
# 125 | model.layer_2.1.shortcut                                                | Sequential        | 0
# 126 | model.layer_2.1.batch_norm                                              | BatchNorm2d       | 1 K
# 127 | model.layer_3                                                           | Sequential        | 3 M
# 128 | model.layer_3.0                                                         | SKBlock           | 1 M
# 129 | model.layer_3.0.basic_block                                             | Sequential        | 1 M
# 130 | model.layer_3.0.basic_block.0                                           | Conv2d            | 262 K
# 131 | model.layer_3.0.basic_block.1                                           | BatchNorm2d       | 1 K
# 132 | model.layer_3.0.basic_block.2                                           | ReLU              | 0
# 133 | model.layer_3.0.basic_block.3                                           | SKConvolution     | 330 K
# 134 | model.layer_3.0.basic_block.3.conv_blocks                               | ModuleList        | 280 K
# 135 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 74 K
# 136 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 73 K
# 137 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 1 K
# 138 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 139 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 205 K
# 140 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 204 K
# 141 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 1 K
# 142 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 143 | model.layer_3.0.basic_block.3.attention_block                           | SKAttention       | 50 K
# 144 | model.layer_3.0.basic_block.3.attention_block.z                         | Sequential        | 16 K
# 145 | model.layer_3.0.basic_block.3.attention_block.z.0                       | Linear            | 16 K
# 146 | model.layer_3.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 147 | model.layer_3.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 148 | model.layer_3.0.basic_block.3.attention_block.projection                | ModuleList        | 33 K
# 149 | model.layer_3.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 16 K
# 150 | model.layer_3.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 16 K
# 151 | model.layer_3.0.basic_block.4                                           | BatchNorm2d       | 1 K
# 152 | model.layer_3.0.basic_block.5                                           | ReLU              | 0
# 153 | model.layer_3.0.basic_block.6                                           | Conv2d            | 524 K
# 154 | model.layer_3.0.basic_block.7                                           | BatchNorm2d       | 2 K
# 155 | model.layer_3.0.shortcut                                                | Sequential        | 524 K
# 156 | model.layer_3.0.shortcut.0                                              | Conv2d            | 524 K
# 157 | model.layer_3.0.batch_norm                                              | BatchNorm2d       | 2 K
# 158 | model.layer_3.1                                                         | SKBlock           | 1 M
# 159 | model.layer_3.1.basic_block                                             | Sequential        | 1 M
# 160 | model.layer_3.1.basic_block.0                                           | Conv2d            | 524 K
# 161 | model.layer_3.1.basic_block.1                                           | BatchNorm2d       | 1 K
# 162 | model.layer_3.1.basic_block.2                                           | ReLU              | 0
# 163 | model.layer_3.1.basic_block.3                                           | SKConvolution     | 330 K
# 164 | model.layer_3.1.basic_block.3.conv_blocks                               | ModuleList        | 280 K
# 165 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 74 K
# 166 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 73 K
# 167 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 1 K
# 168 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 169 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 205 K
# 170 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 204 K
# 171 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 1 K
# 172 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 173 | model.layer_3.1.basic_block.3.attention_block                           | SKAttention       | 50 K
# 174 | model.layer_3.1.basic_block.3.attention_block.z                         | Sequential        | 16 K
# 175 | model.layer_3.1.basic_block.3.attention_block.z.0                       | Linear            | 16 K
# 176 | model.layer_3.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 177 | model.layer_3.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 178 | model.layer_3.1.basic_block.3.attention_block.projection                | ModuleList        | 33 K
# 179 | model.layer_3.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 16 K
# 180 | model.layer_3.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 16 K
# 181 | model.layer_3.1.basic_block.4                                           | BatchNorm2d       | 1 K
# 182 | model.layer_3.1.basic_block.5                                           | ReLU              | 0
# 183 | model.layer_3.1.basic_block.6                                           | Conv2d            | 524 K
# 184 | model.layer_3.1.basic_block.7                                           | BatchNorm2d       | 2 K
# 185 | model.layer_3.1.shortcut                                                | Sequential        | 0
# 186 | model.layer_3.1.batch_norm                                              | BatchNorm2d       | 2 K
# 187 | model.layer_4                                                           | Sequential        | 12 M
# 188 | model.layer_4.0                                                         | SKBlock           | 6 M
# 189 | model.layer_4.0.basic_block                                             | Sequential        | 4 M
# 190 | model.layer_4.0.basic_block.0                                           | Conv2d            | 1 M
# 191 | model.layer_4.0.basic_block.1                                           | BatchNorm2d       | 2 K
# 192 | model.layer_4.0.basic_block.2                                           | ReLU              | 0
# 193 | model.layer_4.0.basic_block.3                                           | SKConvolution     | 1 M
# 194 | model.layer_4.0.basic_block.3.conv_blocks                               | ModuleList        | 1 M
# 195 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 296 K
# 196 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 294 K
# 197 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 2 K
# 198 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 199 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 821 K
# 200 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 819 K
# 201 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 2 K
# 202 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 203 | model.layer_4.0.basic_block.3.attention_block                           | SKAttention       | 198 K
# 204 | model.layer_4.0.basic_block.3.attention_block.z                         | Sequential        | 65 K
# 205 | model.layer_4.0.basic_block.3.attention_block.z.0                       | Linear            | 65 K
# 206 | model.layer_4.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 128
# 207 | model.layer_4.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 208 | model.layer_4.0.basic_block.3.attention_block.projection                | ModuleList        | 133 K
# 209 | model.layer_4.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 66 K
# 210 | model.layer_4.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 66 K
# 211 | model.layer_4.0.basic_block.4                                           | BatchNorm2d       | 2 K
# 212 | model.layer_4.0.basic_block.5                                           | ReLU              | 0
# 213 | model.layer_4.0.basic_block.6                                           | Conv2d            | 2 M
# 214 | model.layer_4.0.basic_block.7                                           | BatchNorm2d       | 4 K
# 215 | model.layer_4.0.shortcut                                                | Sequential        | 2 M
# 216 | model.layer_4.0.shortcut.0                                              | Conv2d            | 2 M
# 217 | model.layer_4.0.batch_norm                                              | BatchNorm2d       | 4 K
# 218 | model.layer_4.1                                                         | SKBlock           | 5 M
# 219 | model.layer_4.1.basic_block                                             | Sequential        | 5 M
# 220 | model.layer_4.1.basic_block.0                                           | Conv2d            | 2 M
# 221 | model.layer_4.1.basic_block.1                                           | BatchNorm2d       | 2 K
# 222 | model.layer_4.1.basic_block.2                                           | ReLU              | 0
# 223 | model.layer_4.1.basic_block.3                                           | SKConvolution     | 1 M
# 224 | model.layer_4.1.basic_block.3.conv_blocks                               | ModuleList        | 1 M
# 225 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 296 K
# 226 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 294 K
# 227 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 2 K
# 228 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 229 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 821 K
# 230 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 819 K
# 231 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 2 K
# 232 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 233 | model.layer_4.1.basic_block.3.attention_block                           | SKAttention       | 198 K
# 234 | model.layer_4.1.basic_block.3.attention_block.z                         | Sequential        | 65 K
# 235 | model.layer_4.1.basic_block.3.attention_block.z.0                       | Linear            | 65 K
# 236 | model.layer_4.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 128
# 237 | model.layer_4.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 238 | model.layer_4.1.basic_block.3.attention_block.projection                | ModuleList        | 133 K
# 239 | model.layer_4.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 66 K
# 240 | model.layer_4.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 66 K
# 241 | model.layer_4.1.basic_block.4                                           | BatchNorm2d       | 2 K
# 242 | model.layer_4.1.basic_block.5                                           | ReLU              | 0
# 243 | model.layer_4.1.basic_block.6                                           | Conv2d            | 2 M
# 244 | model.layer_4.1.basic_block.7                                           | BatchNorm2d       | 4 K
# 245 | model.layer_4.1.shortcut                                                | Sequential        | 0
# 246 | model.layer_4.1.batch_norm                                              | BatchNorm2d       | 4 K
# 247 | model.fc                                                                | Linear            | 2 K
# HBox(children=(FloatProgress(value=0.0, description='Finding best initial lr', style=ProgressStyle(description…

# %%
fig = lr_finder.plot(suggest = True)

# %%
sknet_trainer.base_lr = 1e-4
sknet_trainer.max_lr = 1e-4
sknet_trainer.configure_optimizers()
# Out:
# SGD (
# Parameter Group 0
#     base_momentum: 0.85
#     dampening: 0
#     initial_lr: 4e-06
#     lr: 4.000000000000002e-06
#     max_lr: 0.0001
#     max_momentum: 0.95
#     min_lr: 3.9999999999999996e-10
#     momentum: 0.95
#     nesterov: True
#     weight_decay: 0.0001
# )

# %% [markdown]
# # Start to train the model

# %%
trainer.fit(sknet_trainer)
# Out:
# INFO:lightning:
#     | Name                                                                    | Type              | Params
# ----------------------------------------------------------------------------------------------------------
# 0   | criterion                                                               | BCEWithLogitsLoss | 0
# 1   | model                                                                   | SKNet             | 16 M
# 2   | model.stem_head                                                         | Sequential        | 9 K
# 3   | model.stem_head.0                                                       | Conv2d            | 9 K
# 4   | model.stem_head.1                                                       | BatchNorm2d       | 128
# 5   | model.stem_head.2                                                       | ReLU              | 0
# 6   | model.stem_head.3                                                       | MaxPool2d         | 0
# 7   | model.layer_1                                                           | Sequential        | 187 K
# 8   | model.layer_1.0                                                         | SKBlock           | 89 K
# 9   | model.layer_1.0.basic_block                                             | Sequential        | 72 K
# 10  | model.layer_1.0.basic_block.0                                           | Conv2d            | 8 K
# 11  | model.layer_1.0.basic_block.1                                           | BatchNorm2d       | 256
# 12  | model.layer_1.0.basic_block.2                                           | ReLU              | 0
# 13  | model.layer_1.0.basic_block.3                                           | SKConvolution     | 30 K
# 14  | model.layer_1.0.basic_block.3.conv_blocks                               | ModuleList        | 17 K
# 15  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 4 K
# 16  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 4 K
# 17  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 256
# 18  | model.layer_1.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 19  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 13 K
# 20  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 12 K
# 21  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 256
# 22  | model.layer_1.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 23  | model.layer_1.0.basic_block.3.attention_block                           | SKAttention       | 12 K
# 24  | model.layer_1.0.basic_block.3.attention_block.z                         | Sequential        | 4 K
# 25  | model.layer_1.0.basic_block.3.attention_block.z.0                       | Linear            | 4 K
# 26  | model.layer_1.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 27  | model.layer_1.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 28  | model.layer_1.0.basic_block.3.attention_block.projection                | ModuleList        | 8 K
# 29  | model.layer_1.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 4 K
# 30  | model.layer_1.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 4 K
# 31  | model.layer_1.0.basic_block.4                                           | BatchNorm2d       | 256
# 32  | model.layer_1.0.basic_block.5                                           | ReLU              | 0
# 33  | model.layer_1.0.basic_block.6                                           | Conv2d            | 32 K
# 34  | model.layer_1.0.basic_block.7                                           | BatchNorm2d       | 512
# 35  | model.layer_1.0.shortcut                                                | Sequential        | 16 K
# 36  | model.layer_1.0.shortcut.0                                              | Conv2d            | 16 K
# 37  | model.layer_1.0.batch_norm                                              | BatchNorm2d       | 512
# 38  | model.layer_1.1                                                         | SKBlock           | 97 K
# 39  | model.layer_1.1.basic_block                                             | Sequential        | 97 K
# 40  | model.layer_1.1.basic_block.0                                           | Conv2d            | 32 K
# 41  | model.layer_1.1.basic_block.1                                           | BatchNorm2d       | 256
# 42  | model.layer_1.1.basic_block.2                                           | ReLU              | 0
# 43  | model.layer_1.1.basic_block.3                                           | SKConvolution     | 30 K
# 44  | model.layer_1.1.basic_block.3.conv_blocks                               | ModuleList        | 17 K
# 45  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 4 K
# 46  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 4 K
# 47  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 256
# 48  | model.layer_1.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 49  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 13 K
# 50  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 12 K
# 51  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 256
# 52  | model.layer_1.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 53  | model.layer_1.1.basic_block.3.attention_block                           | SKAttention       | 12 K
# 54  | model.layer_1.1.basic_block.3.attention_block.z                         | Sequential        | 4 K
# 55  | model.layer_1.1.basic_block.3.attention_block.z.0                       | Linear            | 4 K
# 56  | model.layer_1.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 57  | model.layer_1.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 58  | model.layer_1.1.basic_block.3.attention_block.projection                | ModuleList        | 8 K
# 59  | model.layer_1.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 4 K
# 60  | model.layer_1.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 4 K
# 61  | model.layer_1.1.basic_block.4                                           | BatchNorm2d       | 256
# 62  | model.layer_1.1.basic_block.5                                           | ReLU              | 0
# 63  | model.layer_1.1.basic_block.6                                           | Conv2d            | 32 K
# 64  | model.layer_1.1.basic_block.7                                           | BatchNorm2d       | 512
# 65  | model.layer_1.1.shortcut                                                | Sequential        | 0
# 66  | model.layer_1.1.batch_norm                                              | BatchNorm2d       | 512
# 67  | model.layer_2                                                           | Sequential        | 787 K
# 68  | model.layer_2.0                                                         | SKBlock           | 426 K
# 69  | model.layer_2.0.basic_block                                             | Sequential        | 294 K
# 70  | model.layer_2.0.basic_block.0                                           | Conv2d            | 65 K
# 71  | model.layer_2.0.basic_block.1                                           | BatchNorm2d       | 512
# 72  | model.layer_2.0.basic_block.2                                           | ReLU              | 0
# 73  | model.layer_2.0.basic_block.3                                           | SKConvolution     | 95 K
# 74  | model.layer_2.0.basic_block.3.conv_blocks                               | ModuleList        | 70 K
# 75  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 18 K
# 76  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 18 K
# 77  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 512
# 78  | model.layer_2.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 79  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 51 K
# 80  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 51 K
# 81  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 512
# 82  | model.layer_2.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 83  | model.layer_2.0.basic_block.3.attention_block                           | SKAttention       | 25 K
# 84  | model.layer_2.0.basic_block.3.attention_block.z                         | Sequential        | 8 K
# 85  | model.layer_2.0.basic_block.3.attention_block.z.0                       | Linear            | 8 K
# 86  | model.layer_2.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 87  | model.layer_2.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 88  | model.layer_2.0.basic_block.3.attention_block.projection                | ModuleList        | 16 K
# 89  | model.layer_2.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 8 K
# 90  | model.layer_2.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 8 K
# 91  | model.layer_2.0.basic_block.4                                           | BatchNorm2d       | 512
# 92  | model.layer_2.0.basic_block.5                                           | ReLU              | 0
# 93  | model.layer_2.0.basic_block.6                                           | Conv2d            | 131 K
# 94  | model.layer_2.0.basic_block.7                                           | BatchNorm2d       | 1 K
# 95  | model.layer_2.0.shortcut                                                | Sequential        | 131 K
# 96  | model.layer_2.0.shortcut.0                                              | Conv2d            | 131 K
# 97  | model.layer_2.0.batch_norm                                              | BatchNorm2d       | 1 K
# 98  | model.layer_2.1                                                         | SKBlock           | 361 K
# 99  | model.layer_2.1.basic_block                                             | Sequential        | 360 K
# 100 | model.layer_2.1.basic_block.0                                           | Conv2d            | 131 K
# 101 | model.layer_2.1.basic_block.1                                           | BatchNorm2d       | 512
# 102 | model.layer_2.1.basic_block.2                                           | ReLU              | 0
# 103 | model.layer_2.1.basic_block.3                                           | SKConvolution     | 95 K
# 104 | model.layer_2.1.basic_block.3.conv_blocks                               | ModuleList        | 70 K
# 105 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 18 K
# 106 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 18 K
# 107 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 512
# 108 | model.layer_2.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 109 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 51 K
# 110 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 51 K
# 111 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 512
# 112 | model.layer_2.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 113 | model.layer_2.1.basic_block.3.attention_block                           | SKAttention       | 25 K
# 114 | model.layer_2.1.basic_block.3.attention_block.z                         | Sequential        | 8 K
# 115 | model.layer_2.1.basic_block.3.attention_block.z.0                       | Linear            | 8 K
# 116 | model.layer_2.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 117 | model.layer_2.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 118 | model.layer_2.1.basic_block.3.attention_block.projection                | ModuleList        | 16 K
# 119 | model.layer_2.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 8 K
# 120 | model.layer_2.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 8 K
# 121 | model.layer_2.1.basic_block.4                                           | BatchNorm2d       | 512
# 122 | model.layer_2.1.basic_block.5                                           | ReLU              | 0
# 123 | model.layer_2.1.basic_block.6                                           | Conv2d            | 131 K
# 124 | model.layer_2.1.basic_block.7                                           | BatchNorm2d       | 1 K
# 125 | model.layer_2.1.shortcut                                                | Sequential        | 0
# 126 | model.layer_2.1.batch_norm                                              | BatchNorm2d       | 1 K
# 127 | model.layer_3                                                           | Sequential        | 3 M
# 128 | model.layer_3.0                                                         | SKBlock           | 1 M
# 129 | model.layer_3.0.basic_block                                             | Sequential        | 1 M
# 130 | model.layer_3.0.basic_block.0                                           | Conv2d            | 262 K
# 131 | model.layer_3.0.basic_block.1                                           | BatchNorm2d       | 1 K
# 132 | model.layer_3.0.basic_block.2                                           | ReLU              | 0
# 133 | model.layer_3.0.basic_block.3                                           | SKConvolution     | 330 K
# 134 | model.layer_3.0.basic_block.3.conv_blocks                               | ModuleList        | 280 K
# 135 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 74 K
# 136 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 73 K
# 137 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 1 K
# 138 | model.layer_3.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 139 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 205 K
# 140 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 204 K
# 141 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 1 K
# 142 | model.layer_3.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 143 | model.layer_3.0.basic_block.3.attention_block                           | SKAttention       | 50 K
# 144 | model.layer_3.0.basic_block.3.attention_block.z                         | Sequential        | 16 K
# 145 | model.layer_3.0.basic_block.3.attention_block.z.0                       | Linear            | 16 K
# 146 | model.layer_3.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 147 | model.layer_3.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 148 | model.layer_3.0.basic_block.3.attention_block.projection                | ModuleList        | 33 K
# 149 | model.layer_3.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 16 K
# 150 | model.layer_3.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 16 K
# 151 | model.layer_3.0.basic_block.4                                           | BatchNorm2d       | 1 K
# 152 | model.layer_3.0.basic_block.5                                           | ReLU              | 0
# 153 | model.layer_3.0.basic_block.6                                           | Conv2d            | 524 K
# 154 | model.layer_3.0.basic_block.7                                           | BatchNorm2d       | 2 K
# 155 | model.layer_3.0.shortcut                                                | Sequential        | 524 K
# 156 | model.layer_3.0.shortcut.0                                              | Conv2d            | 524 K
# 157 | model.layer_3.0.batch_norm                                              | BatchNorm2d       | 2 K
# 158 | model.layer_3.1                                                         | SKBlock           | 1 M
# 159 | model.layer_3.1.basic_block                                             | Sequential        | 1 M
# 160 | model.layer_3.1.basic_block.0                                           | Conv2d            | 524 K
# 161 | model.layer_3.1.basic_block.1                                           | BatchNorm2d       | 1 K
# 162 | model.layer_3.1.basic_block.2                                           | ReLU              | 0
# 163 | model.layer_3.1.basic_block.3                                           | SKConvolution     | 330 K
# 164 | model.layer_3.1.basic_block.3.conv_blocks                               | ModuleList        | 280 K
# 165 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 74 K
# 166 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 73 K
# 167 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 1 K
# 168 | model.layer_3.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 169 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 205 K
# 170 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 204 K
# 171 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 1 K
# 172 | model.layer_3.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 173 | model.layer_3.1.basic_block.3.attention_block                           | SKAttention       | 50 K
# 174 | model.layer_3.1.basic_block.3.attention_block.z                         | Sequential        | 16 K
# 175 | model.layer_3.1.basic_block.3.attention_block.z.0                       | Linear            | 16 K
# 176 | model.layer_3.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 64
# 177 | model.layer_3.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 178 | model.layer_3.1.basic_block.3.attention_block.projection                | ModuleList        | 33 K
# 179 | model.layer_3.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 16 K
# 180 | model.layer_3.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 16 K
# 181 | model.layer_3.1.basic_block.4                                           | BatchNorm2d       | 1 K
# 182 | model.layer_3.1.basic_block.5                                           | ReLU              | 0
# 183 | model.layer_3.1.basic_block.6                                           | Conv2d            | 524 K
# 184 | model.layer_3.1.basic_block.7                                           | BatchNorm2d       | 2 K
# 185 | model.layer_3.1.shortcut                                                | Sequential        | 0
# 186 | model.layer_3.1.batch_norm                                              | BatchNorm2d       | 2 K
# 187 | model.layer_4                                                           | Sequential        | 12 M
# 188 | model.layer_4.0                                                         | SKBlock           | 6 M
# 189 | model.layer_4.0.basic_block                                             | Sequential        | 4 M
# 190 | model.layer_4.0.basic_block.0                                           | Conv2d            | 1 M
# 191 | model.layer_4.0.basic_block.1                                           | BatchNorm2d       | 2 K
# 192 | model.layer_4.0.basic_block.2                                           | ReLU              | 0
# 193 | model.layer_4.0.basic_block.3                                           | SKConvolution     | 1 M
# 194 | model.layer_4.0.basic_block.3.conv_blocks                               | ModuleList        | 1 M
# 195 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 296 K
# 196 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 294 K
# 197 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 2 K
# 198 | model.layer_4.0.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 199 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 821 K
# 200 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 819 K
# 201 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 2 K
# 202 | model.layer_4.0.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 203 | model.layer_4.0.basic_block.3.attention_block                           | SKAttention       | 198 K
# 204 | model.layer_4.0.basic_block.3.attention_block.z                         | Sequential        | 65 K
# 205 | model.layer_4.0.basic_block.3.attention_block.z.0                       | Linear            | 65 K
# 206 | model.layer_4.0.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 128
# 207 | model.layer_4.0.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 208 | model.layer_4.0.basic_block.3.attention_block.projection                | ModuleList        | 133 K
# 209 | model.layer_4.0.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 66 K
# 210 | model.layer_4.0.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 66 K
# 211 | model.layer_4.0.basic_block.4                                           | BatchNorm2d       | 2 K
# 212 | model.layer_4.0.basic_block.5                                           | ReLU              | 0
# 213 | model.layer_4.0.basic_block.6                                           | Conv2d            | 2 M
# 214 | model.layer_4.0.basic_block.7                                           | BatchNorm2d       | 4 K
# 215 | model.layer_4.0.shortcut                                                | Sequential        | 2 M
# 216 | model.layer_4.0.shortcut.0                                              | Conv2d            | 2 M
# 217 | model.layer_4.0.batch_norm                                              | BatchNorm2d       | 4 K
# 218 | model.layer_4.1                                                         | SKBlock           | 5 M
# 219 | model.layer_4.1.basic_block                                             | Sequential        | 5 M
# 220 | model.layer_4.1.basic_block.0                                           | Conv2d            | 2 M
# 221 | model.layer_4.1.basic_block.1                                           | BatchNorm2d       | 2 K
# 222 | model.layer_4.1.basic_block.2                                           | ReLU              | 0
# 223 | model.layer_4.1.basic_block.3                                           | SKConvolution     | 1 M
# 224 | model.layer_4.1.basic_block.3.conv_blocks                               | ModuleList        | 1 M
# 225 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3                     | Sequential        | 296 K
# 226 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3.0                   | Conv2d            | 294 K
# 227 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3.1                   | BatchNorm2d       | 2 K
# 228 | model.layer_4.1.basic_block.3.conv_blocks.layer_3x3.2                   | ReLU              | 0
# 229 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5                     | Sequential        | 821 K
# 230 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5.0                   | Conv2d            | 819 K
# 231 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5.1                   | BatchNorm2d       | 2 K
# 232 | model.layer_4.1.basic_block.3.conv_blocks.layer_5x5.2                   | ReLU              | 0
# 233 | model.layer_4.1.basic_block.3.attention_block                           | SKAttention       | 198 K
# 234 | model.layer_4.1.basic_block.3.attention_block.z                         | Sequential        | 65 K
# 235 | model.layer_4.1.basic_block.3.attention_block.z.0                       | Linear            | 65 K
# 236 | model.layer_4.1.basic_block.3.attention_block.z.1                       | BatchNorm1d       | 128
# 237 | model.layer_4.1.basic_block.3.attention_block.z.2                       | ReLU              | 0
# 238 | model.layer_4.1.basic_block.3.attention_block.projection                | ModuleList        | 133 K
# 239 | model.layer_4.1.basic_block.3.attention_block.projection.projection_0x0 | Linear            | 66 K
# 240 | model.layer_4.1.basic_block.3.attention_block.projection.projection_1x1 | Linear            | 66 K
# 241 | model.layer_4.1.basic_block.4                                           | BatchNorm2d       | 2 K
# 242 | model.layer_4.1.basic_block.5                                           | ReLU              | 0
# 243 | model.layer_4.1.basic_block.6                                           | Conv2d            | 2 M
# 244 | model.layer_4.1.basic_block.7                                           | BatchNorm2d       | 4 K
# 245 | model.layer_4.1.shortcut                                                | Sequential        | 0
# 246 | model.layer_4.1.batch_norm                                              | BatchNorm2d       | 4 K
# 247 | model.fc                                                                | Linear            | 2 K
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00000: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_0.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00001: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00002: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_2.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00003: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_3.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00004: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_4.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00005: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_5.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00006: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_6.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00007: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_7.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00008: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_8.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00009: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_9.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00010: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_10.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00011: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_11.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00012: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_12.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00013: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_13.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00014: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_14.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00015: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_15.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00016: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_16.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00017: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_17.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00018: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_18.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00019: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_19.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00020: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_20.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00021: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_21.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00022: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_22.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00023: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_23.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00024: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_24.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00025: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_25.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00026: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_26.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00027: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_27.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00028: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_28.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00029: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/sknet/_ckpt_epoch_29.ckpt
# 1

# %% [markdown]
# # Evaluate the model

# %% [markdown]
# ## Run test set

# %%
from evaluate.evaluator import Evaluator
from trainer.sknet_trainer import SKNetTrainer

checkpoint_path = ["checkpoint/eval/sknet/small/epoch={}.ckpt".format(x) for x in range(1, 20)]
evaluator = Evaluator(SKNetTrainer, "SKNet", checkpoint_path, trainloader, valloader, valset, "logs/eval/sknet/version2/")

# %%
evaluator.run_validation()
# Out:
# >> Evaluate checkpoint/eval/sknet/full/epoch=1.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:52<00:00,  1.34it/s]
# {'accuracy_score/patient-level': 0.786096256684492,
#  'accuracy_score/picture-level': 0.6187605763550251,
#  'auc_score/patient-level': 0.7072279892349096,
#  'auc_score/picture-level': 0.5959163358104637,
#  'f1_score/patient-level': 0.8773006134969324,
#  'f1_score/picture-level': 0.7240774560106676,
#  'precision_score/patient-level': 0.8265895953757225,
#  'precision_score/picture-level': 0.6658358767943062,
#  'recall_score/patient-level': 0.934640522875817,
#  'recall_score/picture-level': 0.793484648739656}
# >> Evaluate checkpoint/eval/sknet/full/epoch=2.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:57<00:00,  1.31it/s]
# {'accuracy_score/patient-level': 0.5508021390374331,
#  'accuracy_score/picture-level': 0.6179695400975278,
#  'auc_score/patient-level': 0.8412149173394848,
#  'auc_score/picture-level': 0.7783698674614477,
#  'f1_score/patient-level': 0.625,
#  'f1_score/picture-level': 0.6149778490912577,
#  'precision_score/patient-level': 0.9859154929577465,
#  'precision_score/picture-level': 0.8432501245364477,
#  'recall_score/patient-level': 0.45751633986928103,
#  'recall_score/picture-level': 0.4839657554916692}
# >> Evaluate checkpoint/eval/sknet/full/epoch=3.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [05:01<00:00,  1.30it/s]
# {'accuracy_score/patient-level': 0.7807486631016043,
#  'accuracy_score/picture-level': 0.6981445693858955,
#  'auc_score/patient-level': 0.9038831218762015,
#  'auc_score/picture-level': 0.7856262520001094,
#  'f1_score/patient-level': 0.8487084870848708,
#  'f1_score/picture-level': 0.7342044472658662,
#  'precision_score/patient-level': 0.9745762711864406,
#  'precision_score/picture-level': 0.8251451673636021,
#  'recall_score/patient-level': 0.7516339869281046,
#  'recall_score/picture-level': 0.66131927127178}
# >> Evaluate checkpoint/eval/sknet/full/epoch=4.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:59<00:00,  1.30it/s]
# {'accuracy_score/patient-level': 0.40641711229946526,
#  'accuracy_score/picture-level': 0.5957304068329512,
#  'auc_score/patient-level': 0.9457900807381776,
#  'auc_score/picture-level': 0.8544534295861349,
#  'f1_score/patient-level': 0.43076923076923085,
#  'f1_score/picture-level': 0.5461351679481992,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9343770435050198,
#  'recall_score/patient-level': 0.27450980392156865,
#  'recall_score/picture-level': 0.38582251941739865}
# >> Evaluate checkpoint/eval/sknet/full/epoch=5.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [05:06<00:00,  1.27it/s]
# {'accuracy_score/patient-level': 0.8235294117647058,
#  'accuracy_score/picture-level': 0.6986752645966215,
#  'auc_score/patient-level': 0.962322183775471,
#  'auc_score/picture-level': 0.80987674010552,
#  'f1_score/patient-level': 0.8791208791208792,
#  'f1_score/picture-level': 0.7229031040229832,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.8600411901318961,
#  'recall_score/patient-level': 0.7843137254901961,
#  'recall_score/picture-level': 0.6234851252402357}
# >> Evaluate checkpoint/eval/sknet/full/epoch=6.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:58<00:00,  1.31it/s]
# {'accuracy_score/patient-level': 0.6310160427807486,
#  'accuracy_score/picture-level': 0.6153761427469986,
#  'auc_score/patient-level': 0.8154555940023067,
#  'auc_score/picture-level': 0.7033232989216547,
#  'f1_score/patient-level': 0.7206477732793523,
#  'f1_score/picture-level': 0.6391680913821933,
#  'precision_score/patient-level': 0.9468085106382979,
#  'precision_score/picture-level': 0.7821818599839062,
#  'recall_score/patient-level': 0.5816993464052288,
#  'recall_score/picture-level': 0.540367540780508}
# >> Evaluate checkpoint/eval/sknet/full/epoch=7.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:56<00:00,  1.32it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.9721935735813916,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9952651316916051,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.9780291941928082,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9743521029068668,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9817341444432091}
# >> Evaluate checkpoint/eval/sknet/full/epoch=8.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:49<00:00,  1.35it/s]
# {'accuracy_score/patient-level': 0.8181818181818182,
#  'accuracy_score/picture-level': 0.6628082788452874,
#  'auc_score/patient-level': 0.9171472510572856,
#  'auc_score/picture-level': 0.6958820559981433,
#  'f1_score/patient-level': 0.9,
#  'f1_score/picture-level': 0.7831127427301711,
#  'precision_score/patient-level': 0.8181818181818182,
#  'precision_score/picture-level': 0.658624574783871,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9656284248479169}
# >> Evaluate checkpoint/eval/sknet/full/epoch=9.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 0.9679144385026738,
#  'accuracy_score/picture-level': 0.8711311818482211,
#  'auc_score/patient-level': 0.9969242599000384,
#  'auc_score/picture-level': 0.9411279983534331,
#  'f1_score/patient-level': 0.9805194805194806,
#  'f1_score/picture-level': 0.8998724092861144,
#  'precision_score/patient-level': 0.9741935483870968,
#  'precision_score/picture-level': 0.8819098159415649,
#  'recall_score/patient-level': 0.9869281045751634,
#  'recall_score/picture-level': 0.9185819342746867}
# >> Evaluate checkpoint/eval/sknet/full/epoch=10.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.9300583764731799,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9896445405510879,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.9421967709634974,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9835181921840986,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9042075001191251}
# >> Evaluate checkpoint/eval/sknet/full/epoch=11.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:47<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.995153651283181,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9996207895812987,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.9961516442974365,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9973411453772548,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.994964977207389}
# >> Evaluate checkpoint/eval/sknet/full/epoch=12.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 0.8877005347593583,
#  'accuracy_score/picture-level': 0.7552293504490883,
#  'auc_score/patient-level': 0.9279123414071512,
#  'auc_score/picture-level': 0.8205923097144121,
#  'f1_score/patient-level': 0.9315960912052117,
#  'f1_score/picture-level': 0.8055831709547858,
#  'precision_score/patient-level': 0.9285714285714286,
#  'precision_score/picture-level': 0.806757359500446,
#  'recall_score/patient-level': 0.934640522875817,
#  'recall_score/picture-level': 0.8044123953684144}
# >> Evaluate checkpoint/eval/sknet/full/epoch=13.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 0.8877005347593583,
#  'accuracy_score/picture-level': 0.7791907398692287,
#  'auc_score/patient-level': 0.9988465974625144,
#  'auc_score/picture-level': 0.9037540674088196,
#  'f1_score/patient-level': 0.9357798165137614,
#  'f1_score/picture-level': 0.8494517948087768,
#  'precision_score/patient-level': 0.8793103448275862,
#  'precision_score/picture-level': 0.7448963708856667,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.988151018917073}
# >> Evaluate checkpoint/eval/sknet/full/epoch=14.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.9591064294225435,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9980290859344848,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.966591407349236,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9965421270135785,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9383884750393113}
# >> Evaluate checkpoint/eval/sknet/full/epoch=15.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.37it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.9991989506253192,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9998867929208305,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.9993647163458484,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9992853626387588,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9994440826569673}
# >> Evaluate checkpoint/eval/sknet/full/epoch=16.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.37it/s]
# {'accuracy_score/patient-level': 0.9679144385026738,
#  'accuracy_score/picture-level': 0.8467993070922909,
#  'auc_score/patient-level': 0.9978854286812764,
#  'auc_score/picture-level': 0.9166904778534835,
#  'f1_score/patient-level': 0.9807692307692307,
#  'f1_score/picture-level': 0.8803996060222316,
#  'precision_score/patient-level': 0.9622641509433962,
#  'precision_score/picture-level': 0.8667939107546908,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.8944392382344065}
# >> Evaluate checkpoint/eval/sknet/full/epoch=17.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 0.8609625668449198,
#  'accuracy_score/picture-level': 0.7824450029538695,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9740251833288968,
#  'f1_score/patient-level': 0.9071428571428571,
#  'f1_score/picture-level': 0.7927623734989175,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9922401031469367,
#  'recall_score/patient-level': 0.8300653594771242,
#  'recall_score/picture-level': 0.6600644864117918}
# >> Evaluate checkpoint/eval/sknet/full/epoch=18.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.36it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.982577176100692,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9989580834794676,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.9863168821364537,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9767463593178102,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9960768118934544}
# >> Evaluate checkpoint/eval/sknet/full/epoch=19.ckpt
#   0%|          | 0/391 [00:00<?, ?it/s]
# >> running the evaluation on picture-level and patient-level
# 100%|██████████| 391/391 [04:46<00:00,  1.37it/s]
# {'accuracy_score/patient-level': 1.0,
#  'accuracy_score/picture-level': 0.9993391342658883,
#  'auc_score/patient-level': 1.0,
#  'auc_score/picture-level': 0.9997435765899417,
#  'f1_score/patient-level': 1.0,
#  'f1_score/picture-level': 0.9994755828181863,
#  'precision_score/patient-level': 1.0,
#  'precision_score/picture-level': 0.9999841004849352,
#  'recall_score/patient-level': 1.0,
#  'recall_score/picture-level': 0.9989675820772249}

# %% [markdown]
# ## Run on noise set

# %%
evaluator.run_test_set()
# Out:
# 100%|██████████| 5482/5482 [00:00<00:00, 1587159.14it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
# >> Evaluate speckle noise
# Extracting the test images in /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/data/speckle
# Transform to dataset and loader
# Start evaluating...
# 100%|██████████| 43/43 [00:12<00:00,  3.34it/s]
# 100%|██████████| 5482/5482 [00:00<00:00, 1306875.90it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
# >> Loading table from /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/table/speckle.csv
#
#
# >> Evaluate pepper noise
# Extracting the test images in /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/data/pepper
# Transform to dataset and loader
# Start evaluating...
# 100%|██████████| 43/43 [00:13<00:00,  3.30it/s]
# 100%|██████████| 5482/5482 [00:00<00:00, 116436.47it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
# >> Loading table from /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/table/pepper.csv
#
#
# >> Evaluate salt noise
# Extracting the test images in /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/data/salt
# Transform to dataset and loader
# Start evaluating...
# 100%|██████████| 43/43 [00:13<00:00,  3.26it/s]
# 100%|██████████| 5482/5482 [00:00<00:00, 2029406.40it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
# >> Loading table from /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/table/salt.csv
#
#
# >> Evaluate poisson noise
# Extracting the test images in /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/data/poisson
# Transform to dataset and loader
# Start evaluating...
# 100%|██████████| 43/43 [00:13<00:00,  3.22it/s]
# 100%|██████████| 5482/5482 [00:00<00:00, 1081065.14it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
# >> Loading table from /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/table/poisson.csv
#
#
# >> Evaluate gaussian noise
# Extracting the test images in /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/data/gaussian
# Transform to dataset and loader
# Start evaluating...
# 100%|██████████| 43/43 [00:13<00:00,  3.24it/s]
# >> Loading table from /home/kientiet/Documents/My Project/python/ucla-cs168/evaluate/table/gaussian.csv

# %% [markdown]
# ## Calibrating graph

# %%
evaluator.calibrater.n_bins = 30
evaluator.calibrated_graph("verions1")

# %%
evaluator.calibrater.n_bins = 5
evaluator.calibrated_graph("verions2")

# %%
evaluator.calibrater.n_bins = 15
evaluator.calibrated_graph("verions3")
