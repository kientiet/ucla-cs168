# %%
import torch
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import skimage

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from preprocessing.load_dataset import raw_to_dict

# %%
trainset, valset = raw_to_dict(data_mode = "small")
# trainset, valset = raw_to_dict()
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 1397356.08it/s]
# 100%|██████████| 5000/5000 [00:00<00:00, 796396.92it/s]
# >> Loading msimut at /home/kientiet/Documents/My Project/python/ucla-cs168/data/msimut_small
# >> Total running 5000
#
# >> Loading msimut at /home/kientiet/Documents/My Project/python/ucla-cs168/data/mss_small
# >> Total running 5000
#
# >> Splitting the dataset
#
# >> From dictionary to data instance
#
# >> Done!

# %%
batch_size = 256
trainloader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle = True, num_workers = 4)
valloader = torch.utils.data.DataLoader(valset, batch_size = batch_size, num_workers = 4)
len(trainloader), len(valloader)
# Out:
# (34, 22)

# %%
images, labels = next(iter(trainloader))

print(images.shape, labels.shape)
def imshow_tensor(img):
    inp = img.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    # plt.show()

imshow_tensor(images[0])
# Out:
# torch.Size([256, 3, 224, 224]) torch.Size([256])

# %%
def imshow(img):
    inp = np.clip(img, 0, 1)
    plt.imshow(inp)
    # plt.show()

# %%
image = images[0].numpy().transpose((1, 2, 0))
imshow(image)

# %% [markdown]
# # Gaussian blur

# %%
gaussian = skimage.util.random_noise(image, mode = "gaussian", seed = 42)
plt.imshow(gaussian)
plt.show()

# %% [markdown]
# # Poisson noise

# %%
poisson = skimage.util.random_noise(image, mode = "poisson", seed = 42)
plt.imshow(poisson)
plt.show()

# %%
plotnoise(img, "salt", r,c,4)
plotnoise(img, "pepper", r,c,5)
plotnoise(img, "s&p", r,c,6)
plotnoise(img, "speckle", r,c,7)
