# %% [markdown]
# # Package

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import os
import pytorch_lightning as pl
from pytorch_lightning import loggers
from pytorch_lightning.callbacks import ModelCheckpoint
from tqdm.notebook import tqdm

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Set up environment

# %%
device = "cuda" if torch.cuda.is_available else "cpu"

def format_bytes(size):
    # 2**10 = 1024
    power = 2**10
    n = 0
    power_labels = {0 : '', 1: 'kilo', 2: 'mega', 3: 'giga', 4: 'tera'}
    while size > power:
        size /= power
        n += 1
    return "%.2f" % size, power_labels[n] + 'bytes'

torch.cuda.get_device_name(), format_bytes(torch.cuda.get_device_properties(device).total_memory)
# Out:
# ('GeForce GTX 1080 Ti', ('10.92', 'gigabytes'))

# %% [markdown]
# # Load data

# %%
from preprocessing.load_sup_dataset import load_train_test

# %%
# trainset, valset = raw_to_dict(data_mode = "small")
trainset, valset = load_train_test()
# Out:
# >> Loading the trainset
# Total images are 93408
#
#
#
#
# >> Loading the testset
# Total images are 98904

# %%
batch_size = 256
trainloader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle = True, num_workers = 4)
valloader = torch.utils.data.DataLoader(valset, batch_size = batch_size, shuffle = False, num_workers = 4)
len(trainloader), len(valloader)
# Out:
# (365, 387)

# %%
images, labels = next(iter(trainloader))

print(images.shape, labels.shape)
def imshow(img):
    inp = img.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    # plt.show()

imshow(images[0])
# Out:
# torch.Size([256, 3, 224, 224]) torch.Size([256])

# %% [markdown]
# # Baseline Model

# %%
from trainer.supervised.baseline_trainer import BaseLineTrainer

run_on = "CRC_DX"

# %%
baseline_trainer = BaseLineTrainer(trainloader, valloader, num_cycle = 5, valset = valset, netname = "ResNet18")
max_epochs = baseline_trainer.get_max_epochs()

# %%
checkpoint_path = os.path.join(os.getcwd(), "checkpoint", run_on, "baseline")
checkpoint_callback = ModelCheckpoint(
    filepath = checkpoint_path,
    save_top_k = -1,
    verbose = True,
    monitor = 'val_loss',
    mode = 'min'
)

checkpoint_path
# Out:
# '/home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline'

# %%
tb_logger = loggers.TensorBoardLogger('logs/' + run_on, name = "baseline")
trainer = pl.Trainer(checkpoint_callback = checkpoint_callback,
                     nb_sanity_val_steps=0, 
                     max_epochs = max_epochs, 
                     gpus = -1, 
                    logger = tb_logger
                    )
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# ## Learning finder

# %%
lr_finder = trainer.lr_find(baseline_trainer)
# Out:
# INFO:lightning:
#    | Name                               | Type              | Params
# ---------------------------------------------------------------------
# 0  | criterion                          | BCEWithLogitsLoss | 0
# 1  | model                              | BaseLineModel     | 11 M
# 2  | model.resnet                       | ResNet            | 11 M
# 3  | model.resnet.conv1                 | Conv2d            | 9 K
# 4  | model.resnet.bn1                   | BatchNorm2d       | 128
# 5  | model.resnet.relu                  | ReLU              | 0
# 6  | model.resnet.maxpool               | MaxPool2d         | 0
# 7  | model.resnet.layer1                | Sequential        | 147 K
# 8  | model.resnet.layer1.0              | BasicBlock        | 73 K
# 9  | model.resnet.layer1.0.conv1        | Conv2d            | 36 K
# 10 | model.resnet.layer1.0.bn1          | BatchNorm2d       | 128
# 11 | model.resnet.layer1.0.relu         | ReLU              | 0
# 12 | model.resnet.layer1.0.conv2        | Conv2d            | 36 K
# 13 | model.resnet.layer1.0.bn2          | BatchNorm2d       | 128
# 14 | model.resnet.layer1.1              | BasicBlock        | 73 K
# 15 | model.resnet.layer1.1.conv1        | Conv2d            | 36 K
# 16 | model.resnet.layer1.1.bn1          | BatchNorm2d       | 128
# 17 | model.resnet.layer1.1.relu         | ReLU              | 0
# 18 | model.resnet.layer1.1.conv2        | Conv2d            | 36 K
# 19 | model.resnet.layer1.1.bn2          | BatchNorm2d       | 128
# 20 | model.resnet.layer2                | Sequential        | 525 K
# 21 | model.resnet.layer2.0              | BasicBlock        | 230 K
# 22 | model.resnet.layer2.0.conv1        | Conv2d            | 73 K
# 23 | model.resnet.layer2.0.bn1          | BatchNorm2d       | 256
# 24 | model.resnet.layer2.0.relu         | ReLU              | 0
# 25 | model.resnet.layer2.0.conv2        | Conv2d            | 147 K
# 26 | model.resnet.layer2.0.bn2          | BatchNorm2d       | 256
# 27 | model.resnet.layer2.0.downsample   | Sequential        | 8 K
# 28 | model.resnet.layer2.0.downsample.0 | Conv2d            | 8 K
# 29 | model.resnet.layer2.0.downsample.1 | BatchNorm2d       | 256
# 30 | model.resnet.layer2.1              | BasicBlock        | 295 K
# 31 | model.resnet.layer2.1.conv1        | Conv2d            | 147 K
# 32 | model.resnet.layer2.1.bn1          | BatchNorm2d       | 256
# 33 | model.resnet.layer2.1.relu         | ReLU              | 0
# 34 | model.resnet.layer2.1.conv2        | Conv2d            | 147 K
# 35 | model.resnet.layer2.1.bn2          | BatchNorm2d       | 256
# 36 | model.resnet.layer3                | Sequential        | 2 M
# 37 | model.resnet.layer3.0              | BasicBlock        | 919 K
# 38 | model.resnet.layer3.0.conv1        | Conv2d            | 294 K
# 39 | model.resnet.layer3.0.bn1          | BatchNorm2d       | 512
# 40 | model.resnet.layer3.0.relu         | ReLU              | 0
# 41 | model.resnet.layer3.0.conv2        | Conv2d            | 589 K
# 42 | model.resnet.layer3.0.bn2          | BatchNorm2d       | 512
# 43 | model.resnet.layer3.0.downsample   | Sequential        | 33 K
# 44 | model.resnet.layer3.0.downsample.0 | Conv2d            | 32 K
# 45 | model.resnet.layer3.0.downsample.1 | BatchNorm2d       | 512
# 46 | model.resnet.layer3.1              | BasicBlock        | 1 M
# 47 | model.resnet.layer3.1.conv1        | Conv2d            | 589 K
# 48 | model.resnet.layer3.1.bn1          | BatchNorm2d       | 512
# 49 | model.resnet.layer3.1.relu         | ReLU              | 0
# 50 | model.resnet.layer3.1.conv2        | Conv2d            | 589 K
# 51 | model.resnet.layer3.1.bn2          | BatchNorm2d       | 512
# 52 | model.resnet.layer4                | Sequential        | 8 M
# 53 | model.resnet.layer4.0              | BasicBlock        | 3 M
# 54 | model.resnet.layer4.0.conv1        | Conv2d            | 1 M
# 55 | model.resnet.layer4.0.bn1          | BatchNorm2d       | 1 K
# 56 | model.resnet.layer4.0.relu         | ReLU              | 0
# 57 | model.resnet.layer4.0.conv2        | Conv2d            | 2 M
# 58 | model.resnet.layer4.0.bn2          | BatchNorm2d       | 1 K
# 59 | model.resnet.layer4.0.downsample   | Sequential        | 132 K
# 60 | model.resnet.layer4.0.downsample.0 | Conv2d            | 131 K
# 61 | model.resnet.layer4.0.downsample.1 | BatchNorm2d       | 1 K
# 62 | model.resnet.layer4.1              | BasicBlock        | 4 M
# 63 | model.resnet.layer4.1.conv1        | Conv2d            | 2 M
# 64 | model.resnet.layer4.1.bn1          | BatchNorm2d       | 1 K
# 65 | model.resnet.layer4.1.relu         | ReLU              | 0
# 66 | model.resnet.layer4.1.conv2        | Conv2d            | 2 M
# 67 | model.resnet.layer4.1.bn2          | BatchNorm2d       | 1 K
# 68 | model.resnet.avgpool               | AdaptiveAvgPool2d | 0
# 69 | model.resnet.fc                    | Linear            | 513 K
# 70 | model.output_weight                | Linear            | 1 K
# HBox(children=(FloatProgress(value=0.0, description='Finding best initial lr', style=ProgressStyle(description…
# INFO:lightning:LR finder stopped early due to diverging loss.

# %%
fig = lr_finder.plot(suggest=True)

# %%
baseline_trainer.base_lr = 1e-4
baseline_trainer.max_lr = 1e-2
baseline_trainer.configure_optimizers()
# Out:
# SGD (
# Parameter Group 0
#     base_momentum: 0.85
#     dampening: 0
#     initial_lr: 0.002
#     lr: 0.002
#     max_lr: 0.01
#     max_momentum: 0.95
#     min_lr: 2e-07
#     momentum: 0.95
#     nesterov: False
#     weight_decay: 1e-05
# )

# %% [markdown]
# ## Train model

# %%
trainer.fit(baseline_trainer)
# Out:
# INFO:lightning:
#    | Name                               | Type              | Params
# ---------------------------------------------------------------------
# 0  | criterion                          | BCEWithLogitsLoss | 0
# 1  | model                              | BaseLineModel     | 11 M
# 2  | model.resnet                       | ResNet            | 11 M
# 3  | model.resnet.conv1                 | Conv2d            | 9 K
# 4  | model.resnet.bn1                   | BatchNorm2d       | 128
# 5  | model.resnet.relu                  | ReLU              | 0
# 6  | model.resnet.maxpool               | MaxPool2d         | 0
# 7  | model.resnet.layer1                | Sequential        | 147 K
# 8  | model.resnet.layer1.0              | BasicBlock        | 73 K
# 9  | model.resnet.layer1.0.conv1        | Conv2d            | 36 K
# 10 | model.resnet.layer1.0.bn1          | BatchNorm2d       | 128
# 11 | model.resnet.layer1.0.relu         | ReLU              | 0
# 12 | model.resnet.layer1.0.conv2        | Conv2d            | 36 K
# 13 | model.resnet.layer1.0.bn2          | BatchNorm2d       | 128
# 14 | model.resnet.layer1.1              | BasicBlock        | 73 K
# 15 | model.resnet.layer1.1.conv1        | Conv2d            | 36 K
# 16 | model.resnet.layer1.1.bn1          | BatchNorm2d       | 128
# 17 | model.resnet.layer1.1.relu         | ReLU              | 0
# 18 | model.resnet.layer1.1.conv2        | Conv2d            | 36 K
# 19 | model.resnet.layer1.1.bn2          | BatchNorm2d       | 128
# 20 | model.resnet.layer2                | Sequential        | 525 K
# 21 | model.resnet.layer2.0              | BasicBlock        | 230 K
# 22 | model.resnet.layer2.0.conv1        | Conv2d            | 73 K
# 23 | model.resnet.layer2.0.bn1          | BatchNorm2d       | 256
# 24 | model.resnet.layer2.0.relu         | ReLU              | 0
# 25 | model.resnet.layer2.0.conv2        | Conv2d            | 147 K
# 26 | model.resnet.layer2.0.bn2          | BatchNorm2d       | 256
# 27 | model.resnet.layer2.0.downsample   | Sequential        | 8 K
# 28 | model.resnet.layer2.0.downsample.0 | Conv2d            | 8 K
# 29 | model.resnet.layer2.0.downsample.1 | BatchNorm2d       | 256
# 30 | model.resnet.layer2.1              | BasicBlock        | 295 K
# 31 | model.resnet.layer2.1.conv1        | Conv2d            | 147 K
# 32 | model.resnet.layer2.1.bn1          | BatchNorm2d       | 256
# 33 | model.resnet.layer2.1.relu         | ReLU              | 0
# 34 | model.resnet.layer2.1.conv2        | Conv2d            | 147 K
# 35 | model.resnet.layer2.1.bn2          | BatchNorm2d       | 256
# 36 | model.resnet.layer3                | Sequential        | 2 M
# 37 | model.resnet.layer3.0              | BasicBlock        | 919 K
# 38 | model.resnet.layer3.0.conv1        | Conv2d            | 294 K
# 39 | model.resnet.layer3.0.bn1          | BatchNorm2d       | 512
# 40 | model.resnet.layer3.0.relu         | ReLU              | 0
# 41 | model.resnet.layer3.0.conv2        | Conv2d            | 589 K
# 42 | model.resnet.layer3.0.bn2          | BatchNorm2d       | 512
# 43 | model.resnet.layer3.0.downsample   | Sequential        | 33 K
# 44 | model.resnet.layer3.0.downsample.0 | Conv2d            | 32 K
# 45 | model.resnet.layer3.0.downsample.1 | BatchNorm2d       | 512
# 46 | model.resnet.layer3.1              | BasicBlock        | 1 M
# 47 | model.resnet.layer3.1.conv1        | Conv2d            | 589 K
# 48 | model.resnet.layer3.1.bn1          | BatchNorm2d       | 512
# 49 | model.resnet.layer3.1.relu         | ReLU              | 0
# 50 | model.resnet.layer3.1.conv2        | Conv2d            | 589 K
# 51 | model.resnet.layer3.1.bn2          | BatchNorm2d       | 512
# 52 | model.resnet.layer4                | Sequential        | 8 M
# 53 | model.resnet.layer4.0              | BasicBlock        | 3 M
# 54 | model.resnet.layer4.0.conv1        | Conv2d            | 1 M
# 55 | model.resnet.layer4.0.bn1          | BatchNorm2d       | 1 K
# 56 | model.resnet.layer4.0.relu         | ReLU              | 0
# 57 | model.resnet.layer4.0.conv2        | Conv2d            | 2 M
# 58 | model.resnet.layer4.0.bn2          | BatchNorm2d       | 1 K
# 59 | model.resnet.layer4.0.downsample   | Sequential        | 132 K
# 60 | model.resnet.layer4.0.downsample.0 | Conv2d            | 131 K
# 61 | model.resnet.layer4.0.downsample.1 | BatchNorm2d       | 1 K
# 62 | model.resnet.layer4.1              | BasicBlock        | 4 M
# 63 | model.resnet.layer4.1.conv1        | Conv2d            | 2 M
# 64 | model.resnet.layer4.1.bn1          | BatchNorm2d       | 1 K
# 65 | model.resnet.layer4.1.relu         | ReLU              | 0
# 66 | model.resnet.layer4.1.conv2        | Conv2d            | 2 M
# 67 | model.resnet.layer4.1.bn2          | BatchNorm2d       | 1 K
# 68 | model.resnet.avgpool               | AdaptiveAvgPool2d | 0
# 69 | model.resnet.fc                    | Linear            | 513 K
# 70 | model.output_weight                | Linear            | 1 K
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00001: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=1_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00002: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=2_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00003: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=3_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00004: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=4_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00005: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=5_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00006: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=6_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00007: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=7_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00008: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=8_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00009: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=9_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00010: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=10_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00011: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=11_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00012: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=12_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00013: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=13_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00014: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=14_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00015: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=15_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00016: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=16_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00017: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=17_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00018: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=18_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00019: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=19_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00020: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=20_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00021: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=21_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00022: saving model to /home/kientiet/Documents/My Project/python/ucla-cs168/checkpoint/CRC_DX/baseline/epoch=22_v1.ckpt
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…

# %% [markdown]
# # Evaluate on test set

# %% [markdown]
# ## Run evaluation for test set

# %%
from evaluate.evaluator import Evaluator
from trainer.baseline_trainer import BaseLineTrainer

checkpoint_path = ["checkpoint/eval/baseline/epoch={}_v1.ckpt".format(x) for x in range(1, 20)]
evaluator = Evaluator(BaseLineTrainer, "Base line", checkpoint_path, trainloader, valloader, valset, "logs/eval/baseline/version1/")

# %%
evaluator.run_validation()

# %% [markdown]
# ## Run on noise set

# %%
evaluator.run_test_set()

# %%
import torch.optim as optim
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
optimizer = optim.SGD(baseline_trainer.parameters(), lr = 6e-2)
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr = 6e-2,
                                    epochs = 2,
                                    steps_per_epoch = len(trainloader),
                                      div_factor = 5,
                                      final_div_factor = 1e4
                                     )

lr_logs = []
for _ in range(2):
    for _ in tqdm(trainloader):
        lr_logs.append(optimizer.param_groups[0]["lr"])
        scheduler.step()

plt.plot(lr_logs)
plt.show()

# %%
lr_logs
